# %% [markdown]
# # HALLIBURTON AI - ML CHALLENGE

# %% [markdown]
# Author : __Parth Shukla__

# %% [markdown]
# ## VISUALIZATION ON "LUCAS TOPSOIL ( 2015 ) DATASET "

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Reading The Dataset

# %%
df = pd.read_csv('../data/LUCAS_Topsoil_2015.csv')

# %%
df.head()
# Out:
#    Point_ID Revisited_point  Coarse  Clay  Sand  Silt  pH(CaCl2)  pH(H2O)  \
# 0  34103754              No     NaN   NaN   NaN   NaN        3.9     3.91
# 1  34443774              No     NaN   NaN   NaN   NaN        3.1     3.91
# 2  35163814              No     NaN   NaN   NaN   NaN        4.9     5.48
# 3  32323656              No     NaN   NaN   NaN   NaN        3.0     3.76
# 4  34463934              No    28.0  10.0  46.0  44.0        3.9     4.04
#
#       EC     OC  ...  Elevation  LC1   LU1  Soil_Stones  NUTS_0 NUTS_1 NUTS_2  \
# 0  44.20   25.5  ...        158  H11  U420            1      UK    UKM   UKM8
# 1  46.40  503.5  ...        500  H12  U420            1      UK    UKM   UKM7
# 2  15.85   51.4  ...        404  H11  U420            1      UK    UKM   UKM7
# 3  26.90  470.3  ...        364  H12  U150            1      UK    UKN   UKN1
# 4  28.40   43.1  ...        315  D20  U111            2      UK    UKM   UKM6
#
#    NUTS_3                      LC1_Desc  \
# ...

# %%
df.tail()
# Out:
#        Point_ID Revisited_point  Coarse  Clay  Sand  Silt  pH(CaCl2)  pH(H2O)  \
# 21854  45402772             Yes     NaN   NaN   NaN   NaN        6.9     7.03
# 21855  47722672             Yes     NaN   NaN   NaN   NaN        5.7     5.98
# 21856  45882618             Yes     NaN   NaN   NaN   NaN        6.8     6.99
# 21857  45342706             Yes     NaN   NaN   NaN   NaN        6.0     6.12
# 21858  47742660             Yes     NaN   NaN   NaN   NaN        4.2     4.68
#
#          EC    OC  ...  Elevation  LC1   LU1  Soil_Stones  NUTS_0 NUTS_1  \
# 21854  81.0  49.9  ...        477  E20  U111            3      AT    AT3
# 21855  22.3  19.4  ...        323  E20  U111            1      AT    AT2
# 21856  65.1  53.9  ...        630  E20  U111            1      AT    AT2
# 21857  30.7  24.2  ...        719  E20  U111            1      AT    AT3
# 21858   7.3  26.0  ...        344  C10  U120            1      AT    AT2
#
# ...

# %%
df.isnull().sum()
# Out:
# Point_ID               0
# Revisited_point        0
# Coarse             17601
# Clay               17599
# Sand               17599
# Silt               17599
# pH(CaCl2)              0
# pH(H2O)                0
# EC                     0
# OC                     0
# CaCO3                  0
# P                      0
# N                      0
# K                      0
# Elevation              0
# LC1                    0
# LU1                    0
# Soil_Stones            0
# NUTS_0                 0
# NUTS_1                 0
# NUTS_2                 0
# NUTS_3                 0
# LC1_Desc               0
# LU1_Desc               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21859 entries, 0 to 21858
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Point_ID         21859 non-null  int64
#  1   Revisited_point  21859 non-null  object
#  2   Coarse           4258 non-null   float64
#  3   Clay             4260 non-null   float64
#  4   Sand             4260 non-null   float64
#  5   Silt             4260 non-null   float64
#  6   pH(CaCl2)        21859 non-null  float64
#  7   pH(H2O)          21859 non-null  float64
#  8   EC               21859 non-null  float64
#  9   OC               21859 non-null  float64
#  10  CaCO3            21859 non-null  int64
#  11  P                21859 non-null  float64
#  12  N                21859 non-null  float64
#  13  K                21859 non-null  float64
#  14  Elevation        21859 non-null  int64
#  15  LC1              21859 non-null  object
# ...

# %%
df.describe()
# Out:
#            Point_ID       Coarse         Clay         Sand         Silt  \
# count  2.185900e+04  4258.000000  4260.000000  4260.000000  4260.000000
# mean   4.287592e+07    21.633866    19.207981    37.418779    43.367136
# std    8.177514e+06    14.804102    10.723485    19.170218    12.544561
# min    2.658177e+07     0.000000     0.000000     2.000000     0.000000
# 25%    3.538292e+07    11.000000    11.000000    22.000000    35.000000
# 50%    4.438403e+07    19.000000    18.000000    34.000000    45.000000
# 75%    4.960328e+07    30.000000    26.000000    50.000000    53.000000
# max    6.498167e+07    90.000000    62.000000   100.000000    72.000000
#
#           pH(CaCl2)       pH(H2O)            EC            OC         CaCO3  \
# count  21859.000000  21859.000000  21859.000000  21859.000000  21859.000000
# mean       5.745199      6.130833     26.091462     43.275982     57.268173
# std        1.398392      1.345302     33.339621     76.696684    135.300507
# ...

# %%
df.corr()
# Out:
#              Point_ID    Coarse      Clay      Sand      Silt  pH(CaCl2)  \
# Point_ID     1.000000 -0.247229 -0.010075 -0.039549  0.069144  -0.163294
# Coarse      -0.247229  1.000000  0.020987 -0.055709  0.067211   0.103743
# Clay        -0.010075  0.020987  1.000000 -0.789135  0.351458   0.564601
# Sand        -0.039549 -0.055709 -0.789135  1.000000 -0.851861  -0.359668
# Silt         0.069144  0.067211  0.351458 -0.851861  1.000000   0.067389
# pH(CaCl2)   -0.163294  0.103743  0.564601 -0.359668  0.067389   1.000000
# pH(H2O)     -0.170245  0.102403  0.562431 -0.331972  0.027000   0.988969
# EC          -0.092160  0.027431 -0.086244 -0.091682  0.213315   0.037117
# OC           0.081153  0.116495 -0.294735  0.116775  0.072935  -0.355304
# CaCO3       -0.237338  0.138949  0.385466 -0.197842 -0.027062   0.514421
# P            0.001639 -0.072721 -0.161841  0.109576 -0.029481  -0.112162
# N            0.050536  0.133731 -0.233193 -0.023481  0.234535  -0.278667
# ...

# %%
df.columns
# Out:
# Index(['Point_ID', 'Revisited_point', 'Coarse', 'Clay', 'Sand', 'Silt',
#        'pH(CaCl2)', 'pH(H2O)', 'EC', 'OC', 'CaCO3', 'P', 'N', 'K', 'Elevation',
#        'LC1', 'LU1', 'Soil_Stones', 'NUTS_0', 'NUTS_1', 'NUTS_2', 'NUTS_3',
#        'LC1_Desc', 'LU1_Desc'],
#       dtype='object')

# %%
df = df[['Point_ID', 'Revisited_point', 'Coarse', 'Clay', 'Sand', 'Silt',
       'pH(CaCl2)', 'pH(H2O)', 'EC', 'OC', 'CaCO3', 'P', 'N', 'K', 'Elevation',]]

# %%
df.head()
# Out:
#    Point_ID Revisited_point  Coarse  Clay  Sand  Silt  pH(CaCl2)  pH(H2O)  \
# 0  34103754              No     NaN   NaN   NaN   NaN        3.9     3.91
# 1  34443774              No     NaN   NaN   NaN   NaN        3.1     3.91
# 2  35163814              No     NaN   NaN   NaN   NaN        4.9     5.48
# 3  32323656              No     NaN   NaN   NaN   NaN        3.0     3.76
# 4  34463934              No    28.0  10.0  46.0  44.0        3.9     4.04
#
#       EC     OC  CaCO3      P     N      K  Elevation
# 0  44.20   25.5      0   42.9   2.8   24.6        158
# 1  46.40  503.5      0  164.9  19.9  460.3        500
# 2  15.85   51.4      0   26.9   4.3  173.2        404
# 3  26.90  470.3      0  102.8  16.1  313.0        364
# 4  28.40   43.1      1    6.3   2.3   38.6        315

# %%
df = df.dropna()

# %% [markdown]
# ### Cleaned Data

# %%
df.head()
# Out:
#    Point_ID Revisited_point  Coarse  Clay  Sand  Silt  pH(CaCl2)  pH(H2O)  \
# 4  34463934              No    28.0  10.0  46.0  44.0        3.9     4.04
# 5  33983238              No    18.0  14.0  36.0  50.0        4.2     4.41
# 6  34043240              No    20.0  18.0  35.0  46.0        4.9     5.13
# 7  33723266              No    13.0  14.0  36.0  50.0        4.0     4.16
# 8  34203268              No    34.0  19.0  48.0  34.0        3.7     3.87
#
#       EC    OC  CaCO3     P    N      K  Elevation
# 4  28.40  43.1      1   6.3  2.3   38.6        315
# 5  41.80  32.4      0   7.5  3.3   48.0        137
# 6  32.00  21.1      1  12.4  2.1   36.0        131
# 7  72.40  53.2      0  52.1  4.2  158.5        137
# 8  11.63  16.0      1   3.7  1.0   24.4        514

# %%
df.shape
# Out:
# (4258, 15)

# %%
df.columns
# Out:
# Index(['Point_ID', 'Revisited_point', 'Coarse', 'Clay', 'Sand', 'Silt',
#        'pH(CaCl2)', 'pH(H2O)', 'EC', 'OC', 'CaCO3', 'P', 'N', 'K',
#        'Elevation'],
#       dtype='object')

# %%
df.cov()
# Out:
#                Point_ID        Coarse           Clay          Sand  \
# Point_ID   7.150300e+13 -3.094874e+07 -889614.689849 -6.464227e+06
# Coarse    -3.094874e+07  2.191614e+02       3.332189 -1.581094e+01
# Clay      -8.896147e+05  3.332189e+00     115.023446 -1.622457e+02
# Sand      -6.464227e+06 -1.581094e+01    -162.245676  3.675420e+02
# Silt       7.366654e+06  1.248295e+01      47.268322 -2.048760e+02
# pH(CaCl2) -1.109093e+06  2.101301e+00       8.287489 -9.436522e+00
# pH(H2O)   -1.157164e+06  2.052625e+00       8.169480 -8.618842e+00
# EC        -2.686235e+06  1.332168e+01     -30.386873 -5.758190e+01
# OC         1.258022e+07  1.018408e+02    -186.721562  1.322592e+02
# CaCO3     -1.709354e+08  3.478689e+02     699.130044 -6.414182e+02
# P          6.738431e+06 -3.442325e+01     -55.601241  6.741999e+01
# N          3.464477e+05  6.679769e+00      -8.442220 -1.515251e+00
# K          2.494852e+07  7.203614e+01     725.444720 -9.796909e+02
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_palette('hls')

# %%
sns.countplot(df['Revisited_point'])

plt.title( "Revisited Points Density" , size = 21 )
plt.xlabel( "Revisited Point" , size = 11 )
plt.ylabel( "Density" , size = 11 )
# Out:
# Text(0, 0.5, 'Density')

# %%
df['CaCO3'].value_counts().plot(kind='pie',autopct='%.2f')

plt.title( "CaCO3 Pie Chart" , size = 21 )
# Out:
# Text(0.5, 1.0, 'CaCO3 Pie Chart')

# %%
plt.hist(df['Clay'],bins=11)

plt.title( "Clay Density" , size = 21 )
plt.xlabel( "Clay" , size = 11 )
plt.ylabel( "Density" , size = 11 )
# Out:
# Text(0, 0.5, 'Density')

# %%
sns.distplot(df['Clay'])

plt.title( "Clay Density" , size = 21 )
plt.xlabel( "Clay" , size = 11 )
plt.ylabel( "Density" , size = 11 )
# Out:
# Text(0, 0.5, 'Density')

# %%
sns.scatterplot(data=df,x='Clay',y='Coarse')

plt.title( "Clay vs Coarsity" , size = 21 )
plt.xlabel( "Clay" , size = 11 )
plt.ylabel( "Coarse" , size = 11 )
# Out:
# Text(0, 0.5, 'Coarse')

# %%
sns.distplot(df['Clay'],hist=False)
sns.distplot(df['Coarse'],hist=False)

plt.title( "Clay vs Coarsity" , size = 21 )
plt.xlabel( "Clay" , size = 11 )
plt.ylabel( "Coarse" , size = 11 )
# Out:
# Text(0, 0.5, 'Coarse')

# %%
sns.lineplot(df['Clay'],df['Coarse'])

plt.title( "Clay vs Coarsity" , size = 21 )
plt.xlabel( "Clay" , size = 11 )
plt.ylabel( "Coarse" , size = 11 )
# Out:
# Text(0, 0.5, 'Coarse')

# %%
sns.lineplot(df['Clay'],df['Elevation'])

plt.title( "Clay vs Elevation" , size = 21 )
plt.xlabel( "Clay" , size = 11 )
plt.ylabel( "Elevation" , size = 11 )
# Out:
# Text(0, 0.5, 'Elevation')

# %%
df.corr()['Clay']
# Out:
# Point_ID    -0.009809
# Coarse       0.020987
# Clay         1.000000
# Sand        -0.789090
# Silt         0.351305
# pH(CaCl2)    0.564781
# pH(H2O)      0.562582
# EC          -0.086367
# OC          -0.294827
# CaCO3        0.385466
# P           -0.162137
# N           -0.233301
# K            0.281167
# Elevation   -0.028605
# Name: Clay, dtype: float64

# %%
sns.lineplot(df['Clay'],df['K'])

plt.title( "Clay vs K" , size = 21 )
plt.xlabel( "Clay" , size = 11 )
plt.ylabel( "K" , size = 11 )
# Out:
# Text(0, 0.5, 'K')

# %%
sns.lineplot(df['Clay'],df['P'])

plt.title( "Clay vs P" , size = 21 )
plt.xlabel( "Clay" , size = 11 )
plt.ylabel( "P" , size = 11 )
# Out:
# Text(0, 0.5, 'P')

# %%
sns.lineplot(df['Clay'],df['N'])

plt.title( "Clay vs N" , size = 21 )
plt.xlabel( "Clay" , size = 11 )
plt.ylabel( "N" , size = 11 )
# Out:
# Text(0, 0.5, 'N')

# %%
sns.lineplot(df['Clay'],df['EC'])

plt.title( "Clay vs EC" , size = 21 )
plt.xlabel( "Clay" , size = 11 )
plt.ylabel( "EC" , size = 11 )
# Out:
# Text(0, 0.5, 'EC')

# %%
sns.lineplot(df['Clay'],df['OC'])

plt.title( "Clay vs OC" , size = 21 )
plt.xlabel( "Clay" , size = 11 )
plt.ylabel( "OC" , size = 11 )
# Out:
# Text(0, 0.5, 'OC')

# %%
sns.lineplot(df['Clay'],df['pH(CaCl2)'])

plt.title( "Clay vs pH(CaCl2)" , size = 21 )
plt.xlabel( "Clay" , size = 11 )
plt.ylabel( "pH(CaCl2)" , size = 11 )
# Out:
# Text(0, 0.5, 'pH(CaCl2)')

# %%
sns.lineplot(df['Clay'],df['pH(H2O)'])

plt.title( "Clay vs pH(H2O)" , size = 21 )
plt.xlabel( "Clay" , size = 11 )
plt.ylabel( "pH(H2O)" , size = 11 )
# Out:
# Text(0, 0.5, 'pH(H2O)')

# %%
df.hist(figsize=[21,21])

plt.title( "Density Histogram" , size = 21 )
# Out:
# Text(0.5, 1.0, 'Density Histogram')

# %%
# from pandas_profiling import ProfileReport
# prof = ProfileReport(df)
# prof.to_file(output_file='Visualization.html')
